# %% [markdown]
# ## ProbabilityExerciseSetOne

# %% [markdown]
# ### Problem 2

# %% [markdown]
# Two fair dice are tossed, and the uppermost face of each die is observed. The following events are defined from this random experiment:
#
#  represent the event the uppermost faces sum to five
#
#  represent the event that the product of the uppermost faces is four. For example, die1*die2 = 4
#
#  represent the event that the absolute difference between the uppermost faces is 1. For example, abs(die1 - die2) = 1
#
# Part (a) Find the probability that the uppermost faces do not sum to five.
#  (Use four decimals in your answer)
#
# Part (b) Find P(A OR C)
#  (Use four decimals)
# Part (c) What is the probability that the uppermost faces do not sum to five or are not a product of 4?
#  (use four decimals)
#
# Part (d) Find P(A AND (B OR C))
#  (use four decimals)

# %%
import pprint

l = [1, 2, 3, 4, 5, 6]

add = []
dot = []
diff = []
super_diff = []

for e in l:

    add.append([x+e for x in l])
    # add += [x + e for x in l]

    # dot.append([x*e for x in l])
    dot += [x*e for x in l]

    # diff.append([abs(x - e) for x in l])
    diff += [abs(x - e) for x in l]


    # super_diff += [x + e - abs(x - e) for x in l]

event_A = add.count(5)
event_B = dot.count(4)
event_C = diff.count(1)

event_A_AND_C = 2
event_A_OR_C = event_A + event_C - event_A_AND_C

event_not_A = 36 - event_A
event_not_B = 36 - event_B
event_not_A_AND_not_B = 31
event_not_A_OR_not_B = event_not_A + event_not_B - event_not_A_AND_not_B

event_B_AND_C = 0
event_B_OR_C = event_B + event_C - event_B_AND_C


print(event_B_OR_C/36)
# Out:
# 0.3611111111111111

# %% [markdown]
# ![set_1_problem_2.png](attachment:dc9350c0-3c2a-4ff2-b876-ec1b326b5a3a.png)

# %% [markdown]
# ### Problem 3

# %% [markdown]
# A triangular die is a four-sided die, each side possessing either a number 1, 2, 3, or 4. Two such dice are tossed simultaneously and the bottom faces - the face that each die lands on - is observed. Assume the two dice are fair. Consider the following events:
#
#  A) the bottom-most faces sum to six
#
#  B) each bottom-most face shows an even number
#
#  C) both bottom-most faces show the same number, referred to as doubles

# %%
l = [1, 2, 3, 4]
A = []
B = []
C = []

for e in l:
    # A.append([x+e for x in l])
    A += [x + e for x in l]
    # B.append([1 if (x % 2 == 0) and (e % 2 == 0) else 0 for x in l])
    B += [1 if (x % 2 == 0) and (e % 2 == 0) else 0 for x in l]
    # C.append([1 if x == e else 0 for x in l])
    C += [1 if x == e else 0 for x in l]


event_A = A.count(6)
event_B = B.count(1)
event_C = C.count(1)

event_A_AND_B = 2
event_A_OR_B = event_A + event_B - event_A_AND_B

# %% [markdown]
# ![Screenshot 2022-09-07 at 11.48.38.png](attachment:8e579a9d-2aa0-4282-82ad-0de8721b9595.png)

# %% [markdown]
# ### Problem 6

# %%
from math import comb, factorial

# %%
A = comb(14, 3)/comb(31, 10) 
B = comb(17, 5)*comb(14, 5)/comb(31, 10)
C = 1 - (comb(17, 10) + comb(14, 1)*comb(17, 9))/comb(31, 10)
D = comb(17, 9)*comb(14, 1)/comb(31, 10)
print(round(A, 4), round(B, 4), round(C, 4), round(D, 4))
# Out:
# 0.0 0.2793 0.9919 0.0077

# %% [markdown]
# ### Problem 7

# %%
A = comb(12, 7)*comb(11, 3)/comb(23, 10) 
B = (comb(12, 5)*comb(11, 5) + 
     comb(12, 6)*comb(11, 4) + 
     comb(12, 7)*comb(11, 3) + 
     comb(12, 8)*comb(11, 2) + 
     comb(12, 9)*comb(11, 1) + 
     comb(12, 10)*comb(11, 0))/comb(23, 10) 
print(round(A, 4), round(B, 4))
# Out:
# 0.1142 0.7265

# %% [markdown]
# ### Problem 8

# %%
A = 1 - (6*5*4*3*2)/6**5
B = factorial(5)/6**5  
C = 2*factorial(5)/6**5 
D = 6/6**5
print(round(A, 4), round(B, 4), round(C, 4), round(E, 4))
# Out:
# 0.9074 0.0154 0.0309 0.0008

# %% [markdown]
# ### Classroom

# %%
l = [1, 2, 3, 4, 5, 6]
A = []
B = []
C = []

for e in l:
    A.append([x+e for x in l])
    # A += [x + e for x in l]
    B.append([1 if (x % 2 == 0) and (e % 2 == 0) else 0 for x in l])
    # B += [1 if (x % 2 == 0) and (e % 2 == 0) else 0 for x in l]
    
event_A = A.count(6)
event_B = B.count(1)

event_A_AND_B = 2
event_A_OR_B = event_A + event_B - event_A_AND_B
